# %% [markdown]
# # Data wrangling with `pandas`
#
# Methods/functions for data frames (df):
# * `read_csv(), .to_csv()`
# * `.head(), .tail(), .describe()`
# * `.drop(), .sort_values(), .copy()`
#
# **Attributes** of data frames:
# * `.index`
# * `.columns`
# * `.dtypes`
#
# Methods we've used for separate df columns (and also for entire df):
# * `.astype()`
# * `.isna()`
# * `.notna()`
#
# **Indexing:** `[]`, `.loc[]`

# %% [markdown]
# We will be working with a data set of popular Spotify songs 2000-2019 (taken from [Kaggle](https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019)), which is saved in `data/songs_normalize.csv`

# %%
# import pandas
import pandas as pd

# %%
# read_csv: pandas function; read in the .csv file into a pandas dataframe
df = pd.read_csv("data/songs_normalize.csv")

# %%
# to_csv: METHOD of pandas dataframe; save the pandas dataframe to a csv file
df.to_csv("data/songs.csv")

# %%
# explore the dataframe: number of rows
len(df)
# Out:
# 2000

# %%
# explore the dataframe: .head()
df.head(3)
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# 0        0.3000          0.000018     0.355    0.894   95.053           pop
# 1        0.0103          0.000000     0.612    0.684  148.726     rock, pop
# 2        0.1730          0.000000     0.251    0.278  136.859  pop, country

# %%
# explore the dataframe: .tail()
df.tail(1)
# Out:
#            artist     song  duration_ms  explicit  year  popularity  \
# 1999  Post Malone  Circles       215280     False  2019          85
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1999         0.695   0.762    0    -3.497     1       0.0395         0.192
#
#       instrumentalness  liveness  valence    tempo    genre
# 1999           0.00244    0.0863    0.553  120.042  hip hop

# %%
# explore the dataframe: .describe()
df.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# min       0.000000   -20.514000     0.000000     0.023200      0.000019
# 25%       2.000000    -6.490250     0.000000     0.039600      0.014000
# 50%       6.000000    -5.285000     1.000000     0.059850      0.055700
# 75%       8.000000    -4.167750     1.000000     0.129000      0.176250
# max      11.000000    -0.276000     1.000000     0.576000      0.976000
#
#        instrumentalness     liveness      valence        tempo
# count       2000.000000  2000.000000  2000.000000  2000.000000
# mean           0.015226     0.181216     0.551690   120.122558
# std            0.087771     0.140669     0.220864    26.967112
# min            0.000000     0.021500     0.038100    60.019000
# 25%            0.000000     0.088100     0.386750    98.985750
# 50%            0.000000     0.124000     0.557500   120.021500
# 75%            0.000068     0.241000     0.730000   134.265500
# max            0.985000     0.853000     0.973000   210.851000

# %%
# dataframe (df) attributes: .columns
df.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
# dataframe (df) attributes: .index
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
# dataframe (df) attributes: .dtypes
df.dtypes
# Out:
# artist               object
# song                 object
# duration_ms           int64
# explicit               bool
# year                  int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genre                object
# dtype: object

# %%
# indexing to a single column
df["year"]
# Out:
# 0       2000
# 1       1999
# 2       1999
# 3       2000
# 4       2000
#         ...
# 1995    2019
# 1996    2019
# 1997    2019
# 1998    2019
# 1999    2019
# Name: year, Length: 2000, dtype: int64

# %%
# what data type is a single column?

# %%
# indexing to several columns
df[ ["year", "speechiness"] ]
# Out:
#       year  speechiness
# 0     2000       0.0437
# 1     1999       0.0488
# 2     1999       0.0290
# 3     2000       0.0466
# 4     2000       0.0516
# ...    ...          ...
# 1995  2019       0.0588
# 1996  2019       0.1570
# 1997  2019       0.1090
# 1998  2019       0.0656
# 1999  2019       0.0395
#
# [2000 rows x 2 columns]

# %%
# indexing to a single row
df.loc[20]
# Out:
# artist              Linkin Park
# song                 In the End
# duration_ms              216880
# explicit                  False
# year                       2000
# popularity                   83
# danceability              0.556
# energy                    0.864
# key                           3
# loudness                  -5.87
# mode                          0
# speechiness              0.0584
# acousticness            0.00958
# instrumentalness            0.0
# liveness                  0.209
# valence                     0.4
# tempo                   105.143
# genre               rock, metal
# Name: 20, dtype: object

# %%
# what data type is a single row?

# %%
# indexing to several rows (update: you can do this numpy-style!)
df.loc[3:7]
# Out:
#             artist                 song  duration_ms  explicit  year  \
# 3         Bon Jovi         It's My Life       224493     False  2000
# 4           *NSYNC          Bye Bye Bye       200560     False  2000
# 5            Sisqo           Thong Song       253733      True  1999
# 6           Eminem  The Real Slim Shady       284200      True  2000
# 7  Robbie Williams              Rock DJ       258560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
# 5          69         0.706   0.888    2    -6.959     1       0.0654
# 6          86         0.949   0.661    5    -4.244     0       0.0572
# 7          68         0.708   0.772    7    -4.264     1       0.0322
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 3        0.0263          0.000013    0.3470    0.544  119.992
# 4        0.0408          0.001040    0.0845    0.879  172.656
# 5        0.1190          0.000096    0.0700    0.714  121.549
# 6        0.0302          0.000000    0.0454    0.760  104.504
# 7        0.0267          0.000000    0.4670    0.861  103.035
#
#                genre
# 3        rock, metal
# 4                pop
# 5  hip hop, pop, R&B
# 6            hip hop
# 7          pop, rock

# %%
# changing the data type of one column
# let's convert the "explicit" booleans False/True into integers 0/1
df["explicit"] = df["explicit"].astype(int)
df.dtypes
# Out:
# artist               object
# song                 object
# duration_ms           int64
# explicit              int64
# year                  int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# genre                object
# dtype: object

# %%
# check for missing values in a column
# update: you can also use the ".sum()" method (for pandas dataframes and series)
df["year"].notna().sum()
# Out:
# 2000

# %%
# update: check for missing values in entire dataframe
# update: you can also use the ".sum()" method (for pandas dataframes and series)
df.notna().sum()
# Out:
# artist              2000
# song                2000
# duration_ms         2000
# explicit            2000
# year                2000
# popularity          2000
# danceability        2000
# energy              2000
# key                 2000
# loudness            2000
# mode                2000
# speechiness         2000
# acousticness        2000
# instrumentalness    2000
# liveness            2000
# valence             2000
# tempo               2000
# genre               2000
# dtype: int64

# %%
# ?pd.DataFrame.sum

# %%
# check for available values in a row: .notna()
df.loc[0].notna()
# Out:
# artist              True
# song                True
# duration_ms         True
# explicit            True
# year                True
# popularity          True
# danceability        True
# energy              True
# key                 True
# loudness            True
# mode                True
# speechiness         True
# acousticness        True
# instrumentalness    True
# liveness            True
# valence             True
# tempo               True
# genre               True
# Name: 0, dtype: bool

# %%
# check for available values in entire data frame: .notna()

# %%
# Boolean indexing: filter for only the year 2000
df[ df["year"]==2000 ]
# Out:
#               artist                             song  duration_ms  explicit  \
# 0     Britney Spears           Oops!...I Did It Again       211160         0
# 3           Bon Jovi                     It's My Life       224493         0
# 4             *NSYNC                      Bye Bye Bye       200560         0
# 6             Eminem              The Real Slim Shady       284200         1
# 7    Robbie Williams                          Rock DJ       258560         0
# ..               ...                              ...          ...       ...
# 193              OPM  Heaven Is a Halfpipe (If I Die)       257426         1
# 196              3LW     No More (Baby I'ma Do Right)       263440         0
# 199        Lifehouse              Hanging By A Moment       216360         0
# 215      Linkin Park                       In the End       216880         0
# 236    Kylie Minogue                  Spinning Around       207866         0
#
#      year  popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0    2000          77         0.751   0.834    1    -5.444     0       0.0437
# 3    2000          78         0.551   0.913    0    -4.063     0       0.0466
# 4    2000          65         0.614   0.928    8    -4.806     0       0.0516
# 6    2000          86         0.949   0.661    5    -4.244     0       0.0572
# 7    2000          68         0.708   0.772    7    -4.264     1       0.0322
# ..    ...         ...           ...     ...  ...       ...   ...          ...
# 193  2000          56         0.743   0.894    8    -6.886     1       0.0349
# 196  2000          56         0.721   0.723    2    -7.080     0       0.0631
# 199  2000          61         0.537   0.858    1    -4.903     1       0.0349
# 215  2000          83         0.556   0.864    3    -5.870     0       0.0584
# 236  2000          55         0.761   0.662    6    -7.645     0       0.0548
#
#      acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.300000          0.000018    0.3550    0.894   95.053
# 3        0.026300          0.000013    0.3470    0.544  119.992
# 4        0.040800          0.001040    0.0845    0.879  172.656
# 6        0.030200          0.000000    0.0454    0.760  104.504
# 7        0.026700          0.000000    0.4670    0.861  103.035
# ..            ...               ...       ...      ...      ...
# 193      0.075500          0.002830    0.3670    0.770   95.900
# 196      0.102000          0.000004    0.0651    0.761   88.933
# 199      0.000966          0.000000    0.0812    0.502  124.599
# 215      0.009580          0.000000    0.2090    0.400  105.143
# 236      0.292000          0.000062    0.0956    0.631  120.043
#
#                      genre
# 0                      pop
# 3              rock, metal
# 4                      pop
# 6                  hip hop
# 7                pop, rock
# ..                     ...
# 193                   rock
# 196               pop, R&B
# 199       pop, rock, metal
# 215            rock, metal
# 236  pop, Dance/Electronic
#
# [74 rows x 18 columns]

# %%
# Boolean indexing: filter for ony the year 2000 and pop songs
# use (condition1) & (condition2)
df[ (df["year"]==2000) & (df["genre"]=="pop") ]
# Out:
#               artist                    song  duration_ms  explicit  year  \
# 0     Britney Spears  Oops!...I Did It Again       211160         0  2000
# 4             *NSYNC             Bye Bye Bye       200560         0  2000
# 12      Bomfunk MC's              Freestyler       306333         0  2000
# 17      Alice Deejay        Better Off Alone       214883         0  2000
# 22           Sonique        It Feels So Good       240866         0  2000
# 32           Madonna                   Music       225973         0  2000
# 61              P!nk              Most Girls       298960         0  2000
# 65           Madonna            American Pie       273533         0  2000
# 71              P!nk            There You Go       202800         0  2000
# 72         Vengaboys            Shalala Lala       214819         0  2000
# 83          Westlife                 My Love       231760         0  2000
# 84        All Saints             Pure Shores       268746         0  2000
# 86            *NSYNC        It's Gonna Be Me       191040         0  2000
# 91   Backstreet Boys       Shape of My Heart       230093         0  2000
# 98    Britney Spears                   Lucky       206226         0  2000
# 155          Madonna           Don't Tell Me       280973         0  2000
#
#      popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0            77         0.751   0.834    1    -5.444     0       0.0437
# 4            65         0.614   0.928    8    -4.806     0       0.0516
# 12           55         0.822   0.922   11    -5.798     0       0.0989
# 17           73         0.671   0.880    8    -6.149     0       0.0552
# 22           62         0.634   0.677    5    -7.278     0       0.0304
# 32           58         0.736   0.802    7    -8.527     1       0.0663
# 61           52         0.742   0.732    2    -6.046     0       0.0311
# 65           58         0.631   0.734    5    -7.480     0       0.0360
# 71           55         0.822   0.847   10    -6.729     0       0.0917
# 72           58         0.751   0.901    2    -5.802     1       0.0328
# 83           68         0.491   0.593    0    -5.975     1       0.0255
# 84           62         0.631   0.664    6    -9.197     1       0.0242
# 86           60         0.644   0.874    0    -4.666     0       0.0801
# 91           70         0.575   0.786    9    -4.353     1       0.0296
# 98           65         0.765   0.791    8    -5.707     1       0.0317
# 155          53         0.699   0.618    7    -7.338     1       0.0594
#
#      acousticness  instrumentalness  liveness  valence    tempo genre
# 0         0.30000          0.000018    0.3550    0.894   95.053   pop
# 4         0.04080          0.001040    0.0845    0.879  172.656   pop
# 12        0.02910          0.325000    0.2520    0.568  163.826   pop
# 17        0.00181          0.691000    0.2850    0.782  136.953   pop
# 22        0.01170          0.001030    0.1260    0.558  135.012   pop
# 32        0.00149          0.087600    0.1400    0.871  119.854   pop
# 61        0.04240          0.004460    0.1010    0.694   97.922   pop
# 65        0.34800          0.000000    0.1350    0.591  124.036   pop
# 71        0.08540          0.000000    0.0452    0.668  107.908   pop
# 72        0.05040          0.003080    0.0395    0.973  124.017   pop
# 83        0.09800          0.000000    0.2570    0.328  144.142   pop
# 84        0.04980          0.000420    0.0696    0.407  100.618   pop
# 86        0.04590          0.000002    0.0584    0.882  165.090   pop
# 91        0.25200          0.000000    0.1590    0.518   96.102   pop
# 98        0.26200          0.000154    0.0669    0.966   95.026   pop
# 155       0.05020          0.000925    0.0914    0.679   99.965   pop

# %%
# Boolean indexing: filter only for the years 2005 or 2010
# use (condition1) | (condition2)
df[ (df["year"]==2005) | (df["year"]==2010) ]
# Out:
#               artist                                        song  duration_ms  \
# 60           DJ Ötzi                        Hey Baby (Radio Mix)       219240
# 255            Diddy  I Need a Girl (Pt. 1) [feat. Usher & Loon]       268800
# 360       Snoop Dogg                                   Beautiful       299146
# 442             JoJo                Leave (Get Out) - Radio Edit       242746
# 500     Mariah Carey                          We Belong Together       201400
# ...              ...                                         ...          ...
# 1185            P!nk                             F**kin' Perfect       213413
# 1193            P!nk                            Raise Your Glass       202960
# 1195      Bruno Mars                                   Marry You       230192
# 1196  The Band Perry                              If I Die Young       222773
# 1279  Ellie Goulding                     Lights - Single Version       210853
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 60           0  2010          58         0.666   0.968   10    -3.196     1
# 255          0  2005          63         0.660   0.707    6    -5.758     1
# 360          1  2005          67         0.893   0.740   11    -4.936     0
# 442          0  2005          49         0.656   0.513    5    -8.691     1
# 500          0  2005          69         0.840   0.476    0    -7.918     1
# ...        ...   ...         ...           ...     ...  ...       ...   ...
# 1185         1  2010          60         0.563   0.671    7    -4.788     1
# 1193         1  2010          76         0.700   0.709    7    -5.006     1
# 1195         0  2010          75         0.621   0.820   10    -4.865     1
# 1196         0  2010          64         0.606   0.497    4    -6.611     1
# 1279         0  2010          63         0.682   0.795    8    -6.170     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 60         0.0460        0.1230          0.000000    0.3470    0.834  135.099
# 255        0.2080        0.3970          0.000000    0.2110    0.761   89.279
# 360        0.1320        0.2990          0.000000    0.0881    0.963  101.025
# 442        0.2530        0.1560          0.000064    0.0763    0.464   86.891
# 500        0.0629        0.0264          0.000000    0.0865    0.767  139.987
# ...           ...           ...               ...       ...      ...      ...
# 1185       0.0373        0.0422          0.000000    0.3600    0.450   91.964
# 1193       0.0838        0.0048          0.000000    0.0290    0.624  122.019
# 1195       0.0367        0.3320          0.000000    0.1040    0.452  144.905
# 1196       0.0277        0.3480          0.000000    0.2750    0.362  130.739
# 1279       0.0367        0.0297          0.039100    0.1310    0.780  120.008
#
#                                       genre
# 60    pop, easy listening, Dance/Electronic
# 255                            hip hop, pop
# 360                            hip hop, pop
# 442                       hip hop, pop, R&B
# 500                                pop, R&B
# ...                                     ...
# 1185                                    pop
# 1193                                    pop
# 1195                                    pop
# 1196                                country
# 1279            pop, rock, Dance/Electronic
#
# [211 rows x 18 columns]

# %%
# UPDATE: there is also an .isin() method in pandas
df[ df["year"].isin([2005, 2006, 2007, 2008, 2009, 2010]) ]
# Out:
#               artist                                               song  \
# 60           DJ Ötzi                               Hey Baby (Radio Mix)
# 118              iio                           Rapture (feat.Nadia Ali)
# 138     Ricky Martin  Nobody Wants to Be Lonely (with Christina Agui...
# 255            Diddy         I Need a Girl (Pt. 1) [feat. Usher & Loon]
# 317              DMX                               X Gon' Give It To Ya
# ...              ...                                                ...
# 1185            P!nk                                    F**kin' Perfect
# 1193            P!nk                                   Raise Your Glass
# 1195      Bruno Mars                                          Marry You
# 1196  The Band Perry                                     If I Die Young
# 1279  Ellie Goulding                            Lights - Single Version
#
#       duration_ms  explicit  year  popularity  danceability  energy  key  \
# 60         219240         0  2010          58         0.666   0.968   10
# 118        253586         0  2006          54         0.661   0.855    8
# 138        252706         0  2008          52         0.635   0.854   10
# 255        268800         0  2005          63         0.660   0.707    6
# 317        217586         1  2007          70         0.761   0.899   10
# ...           ...       ...   ...         ...           ...     ...  ...
# 1185       213413         1  2010          60         0.563   0.671    7
# 1193       202960         1  2010          76         0.700   0.709    7
# 1195       230192         0  2010          75         0.621   0.820   10
# 1196       222773         0  2010          64         0.606   0.497    4
# 1279       210853         0  2010          63         0.682   0.795    8
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 60      -3.196     1       0.0460       0.12300            0.0000    0.3470
# 118     -8.403     1       0.0377       0.07220            0.0185    0.1990
# 138     -5.020     0       0.0612       0.00579            0.0083    0.0623
# 255     -5.758     1       0.2080       0.39700            0.0000    0.2110
# 317     -3.090     0       0.1830       0.01350            0.0000    0.0719
# ...        ...   ...          ...           ...               ...       ...
# 1185    -4.788     1       0.0373       0.04220            0.0000    0.3600
# 1193    -5.006     1       0.0838       0.00480            0.0000    0.0290
# 1195    -4.865     1       0.0367       0.33200            0.0000    0.1040
# 1196    -6.611     1       0.0277       0.34800            0.0000    0.2750
# 1279    -6.170     0       0.0367       0.02970            0.0391    0.1310
#
#       valence    tempo                                  genre
# 60      0.834  135.099  pop, easy listening, Dance/Electronic
# 118     0.601  123.943                       Dance/Electronic
# 138     0.590  100.851                             pop, latin
# 255     0.761   89.279                           hip hop, pop
# 317     0.673   95.027                           hip hop, pop
# ...       ...      ...                                    ...
# 1185    0.450   91.964                                    pop
# 1193    0.624  122.019                                    pop
# 1195    0.452  144.905                                    pop
# 1196    0.362  130.739                                country
# 1279    0.780  120.008            pop, rock, Dance/Electronic
#
# [581 rows x 18 columns]

# %%
# saving and manipulating a PART of the dataset: USE .copy() !!!
# save the non-explicit year2000 songs to a separate df, then save the df to csv
nonex2000 = df[ (df["explicit"]==0) & (df["year"]==2000) ].copy()
