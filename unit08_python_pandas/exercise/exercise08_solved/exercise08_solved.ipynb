# %% [markdown]
# **Very first step: import the modules and packages used in this notebook**

# %%
# import pandas under the alias "pd"
import pandas as pd

# %% [markdown]
# # Exercise 08
#
# * Task 1: Getting familiar with pandas
# * Task 2: Read in a csv file without using pandas

# %% [markdown]
# # Task 1: Getting familiar with pandas
#
# Together with this notebook, you are provided the file `oil.csv`, with data provided by [UNdata](http://data.un.org/Explorer.aspx?d=EDATA&f=cmID%3aCR). It contains data on crude oil exports across all countries. For each of the subtasks below, you will find instructions in the code cells. Each of the code cell instructions can be solved by **1-2 lines of code**!
#
# * Task 1a: Read in & explore the data
# * Task 1b: Clean the data
# * Task 1c: Access parts of the data
# * Task 1d: Zoom in on a subset & explore the data
# * Task 1e: Write your manipulated data set to a file

# %% [markdown]
# ## Task 1a: Read in and explore the data

# %%
# read in with pandas
oil = pd.read_csv("oil.csv")

# %%
# display the first 10 rows
oil.head(10)
# Out:
#   Country or Area           Commodity - Transaction    Year  \
# 0         Albania  Conventional crude oil - exports  2021.0
# 1         Albania  Conventional crude oil - exports  2020.0
# 2         Albania  Conventional crude oil - exports  2019.0
# 3         Albania  Conventional crude oil - exports  2018.0
# 4         Albania  Conventional crude oil - exports  2017.0
# 5         Albania  Conventional crude oil - exports  2016.0
# 6         Albania  Conventional crude oil - exports  2015.0
# 7         Albania  Conventional crude oil - exports  2014.0
# 8         Albania  Conventional crude oil - exports  2013.0
# 9         Albania  Conventional crude oil - exports  2012.0
#
#                      Unit  Quantity  Quantity Footnotes
# 0  Metric tons,  thousand   547.800                 NaN
# 1  Metric tons,  thousand   577.320                 NaN
# 2  Metric tons,  thousand   631.216                 NaN
# 3  Metric tons,  thousand   582.789                 NaN
# 4  Metric tons,  thousand   488.000                 NaN
# 5  Metric tons,  thousand   888.000                 NaN
# 6  Metric tons,  thousand   987.000                 NaN
# 7  Metric tons,  thousand  1007.220                 NaN
# 8  Metric tons,  thousand  1167.000                 NaN
# 9  Metric tons,  thousand   920.070                 NaN

# %%
# display the last 8 rows
oil.tail(8)
# Out:
#                Country or Area           Commodity - Transaction    Year  \
# 2367                     Yemen  Conventional crude oil - exports  1993.0
# 2368                     Yemen  Conventional crude oil - exports  1992.0
# 2369                     Yemen  Conventional crude oil - exports  1991.0
# 2370  Yemen Arab Rep. (former)  Conventional crude oil - exports  1990.0
# 2371  Yugoslavia, SFR (former)  Conventional crude oil - exports  1991.0
# 2372  Yugoslavia, SFR (former)  Conventional crude oil - exports  1990.0
# 2373                   fnSeqID                          Footnote     NaN
# 2374                         1                          Estimate     NaN
#
#                         Unit  Quantity  Quantity Footnotes
# 2367  Metric tons,  thousand    8327.0                 NaN
# 2368  Metric tons,  thousand    6153.0                 NaN
# 2369  Metric tons,  thousand    7028.0                 NaN
# 2370  Metric tons,  thousand    8058.0                 1.0
# 2371  Metric tons,  thousand       0.0                 NaN
# 2372  Metric tons,  thousand       0.0                 NaN
# 2373                     NaN       NaN                 NaN
# 2374                     NaN       NaN                 NaN

# %%
# display the names of the columns
oil.columns
# Out:
# Index(['Country or Area', 'Commodity - Transaction', 'Year', 'Unit',
#        'Quantity', 'Quantity Footnotes'],
#       dtype='object')

# %%
# display the data types in the columns
oil.dtypes
# Out:
# Country or Area             object
# Commodity - Transaction     object
# Year                       float64
# Unit                        object
# Quantity                   float64
# Quantity Footnotes         float64
# dtype: object

# %%
# display the row labels (the index)
oil.index
# Out:
# RangeIndex(start=0, stop=2375, step=1)

# %%
# how many rows does the data set have?
len(oil)
# Out:
# 2375

# %%
# display the summary statistics for this dataset
oil.describe()
# Out:
#               Year       Quantity  Quantity Footnotes
# count  2373.000000    2373.000000                38.0
# mean   2005.819638   25629.168283                 1.0
# std       8.918376   53125.712083                 0.0
# min    1990.000000       0.000000                 1.0
# 25%    1998.000000     202.411489                 1.0
# 50%    2006.000000    3100.000000                 1.0
# 75%    2013.000000   21373.000000                 1.0
# max    2021.000000  375945.000000                 1.0

# %% [markdown]
# ## Task 1b: Clean the data
# In this task, we will remove not needed columns, and all rows where we have missing values. Then, we will convert some of the columns into a different data type.

# %%
# remove the columns "Quantity Footnotes" and "Unit"
oil = oil.drop(columns = ["Quantity Footnotes", "Unit"])
# equivalent to: oil.drop(columns = ["Quantity Footnotes", "Unit"], inplace = True)

# %%
# remove rows (if any) where "Country or Area" is not availabe using boolean indexing with ".notna()"
any(oil["Country or Area"].isna()) # there are no missing values in this column
# Out:
# False

# %%
# remove rows (if any) where "Year" is missing 
# any(oil["Year"].isna()) returns True, there are some missing values
oil = oil[oil["Year"].notna()] # keep only rows where Year is not missing

# %%
# remove rows (if any) where "Quantity" is missing
any(oil["Quantity"].isna()) # there are no missing values in this column
# Out:
# False

# %%
# check whether all the rows of "Commodity - Transaction" contain the same value, 
# 'Conventional crude oil - exports' 
all(oil["Commodity - Transaction"] == 'Conventional crude oil - exports') # yes
# Out:
# True

# %%
# how many rows do we have in our data set now?
len(oil)
# Out:
# 2373

# %%
# change the datatype of the "Year" column to integer
oil["Year"] = oil["Year"].astype(int)

# %% [markdown]
# ## Task 1c: Access parts of the data

# %%
# display only the "Country or Area" column
oil["Country or Area"]
# Out:
# 0                        Albania
# 1                        Albania
# 2                        Albania
# 3                        Albania
# 4                        Albania
#                   ...
# 2368                       Yemen
# 2369                       Yemen
# 2370    Yemen Arab Rep. (former)
# 2371    Yugoslavia, SFR (former)
# 2372    Yugoslavia, SFR (former)
# Name: Country or Area, Length: 2373, dtype: object

# %%
# display only the data from the first row of the data set
oil.loc[0]
# Out:
# Country or Area                                     Albania
# Commodity - Transaction    Conventional crude oil - exports
# Year                                                   2021
# Quantity                                              547.8
# Name: 0, dtype: object

# %%
# display the part of the dataset where "Country or Area" is "Costa Rica"
oil[oil["Country or Area"]=="Costa Rica"]
# Out:
#     Country or Area           Commodity - Transaction  Year   Quantity
# 536      Costa Rica  Conventional crude oil - exports  2013   0.000000
# 537      Costa Rica  Conventional crude oil - exports  2012  64.325721
# 538      Costa Rica  Conventional crude oil - exports  2011   0.000000
# 539      Costa Rica  Conventional crude oil - exports  2010   0.000000

# %%
# display the part of the data set that contains data for the year 2010
oil[oil["Year"]==2010]
# Out:
#                 Country or Area           Commodity - Transaction  Year  \
# 11                      Albania  Conventional crude oil - exports  2010
# 28                      Algeria  Conventional crude oil - exports  2010
# 60                       Angola  Conventional crude oil - exports  2010
# 92                    Argentina  Conventional crude oil - exports  2010
# 124                   Australia  Conventional crude oil - exports  2010
# ...                         ...                               ...   ...
# 2214             United Kingdom  Conventional crude oil - exports  2010
# 2246              United States  Conventional crude oil - exports  2010
# 2287  Venezuela (Bolivar. Rep.)  Conventional crude oil - exports  2010
# 2319                   Viet Nam  Conventional crude oil - exports  2010
# 2350                      Yemen  Conventional crude oil - exports  2010
#
#        Quantity
# 11       586.47
# 28     32974.00
# 60     85997.00
# 92      2861.00
# 124    13661.00
# ...         ...
# 2214   36986.00
# 2246    2054.00
# 2287  104984.00
# 2319    8072.00
# 2350    8773.00
#
# [84 rows x 4 columns]

# %%
# display the part of the data set that contains quantities over 200000 
# (two hundred thousand) (in thousand metric tons, unit of the "Quantity" column); 
# who are the big exporters?
oil[oil["Quantity"]>2*10**5]
# Out:
#          Country or Area           Commodity - Transaction  Year     Quantity
# 1756  Russian Federation  Conventional crude oil - exports  2021  231600.0000
# 1757  Russian Federation  Conventional crude oil - exports  2020  239200.0000
# 1758  Russian Federation  Conventional crude oil - exports  2019  269200.0000
# 1759  Russian Federation  Conventional crude oil - exports  2018  259830.0000
# 1760  Russian Federation  Conventional crude oil - exports  2017  252169.0000
# 1761  Russian Federation  Conventional crude oil - exports  2016  252844.0000
# 1762  Russian Federation  Conventional crude oil - exports  2015  242733.0000
# 1763  Russian Federation  Conventional crude oil - exports  2014  222866.0000
# 1764  Russian Federation  Conventional crude oil - exports  2013  236618.0000
# 1765  Russian Federation  Conventional crude oil - exports  2012  239964.0000
# 1766  Russian Federation  Conventional crude oil - exports  2011  244490.0000
# 1767  Russian Federation  Conventional crude oil - exports  2010  243260.0000
# 1768  Russian Federation  Conventional crude oil - exports  2009  248899.0000
# 1769  Russian Federation  Conventional crude oil - exports  2008  243098.0000
# 1770  Russian Federation  Conventional crude oil - exports  2007  258579.0000
# 1771  Russian Federation  Conventional crude oil - exports  2006  248445.0000
# 1772  Russian Federation  Conventional crude oil - exports  2005  252587.0000
# 1773  Russian Federation  Conventional crude oil - exports  2004  257624.0000
# 1774  Russian Federation  Conventional crude oil - exports  2003  227856.0000
# 1786        Saudi Arabia  Conventional crude oil - exports  2021  309427.3000
# 1787        Saudi Arabia  Conventional crude oil - exports  2020  335109.6000
# 1788        Saudi Arabia  Conventional crude oil - exports  2019  350529.0000
# 1789        Saudi Arabia  Conventional crude oil - exports  2018  363997.0000
# 1790        Saudi Arabia  Conventional crude oil - exports  2017  352804.0000
# 1791        Saudi Arabia  Conventional crude oil - exports  2016  371785.0000
# 1792        Saudi Arabia  Conventional crude oil - exports  2015  357171.9500
# 1793        Saudi Arabia  Conventional crude oil - exports  2014  356672.8100
# 1794        Saudi Arabia  Conventional crude oil - exports  2013  375945.0000
# 1795        Saudi Arabia  Conventional crude oil - exports  2012  370327.0000
# 1796        Saudi Arabia  Conventional crude oil - exports  2011  351154.0000
# 1797        Saudi Arabia  Conventional crude oil - exports  2010  288813.0000
# 1798        Saudi Arabia  Conventional crude oil - exports  2009  294854.0000
# 1799        Saudi Arabia  Conventional crude oil - exports  2008  356295.0000
# 1800        Saudi Arabia  Conventional crude oil - exports  2007  342940.0000
# 1801        Saudi Arabia  Conventional crude oil - exports  2006  350365.0000
# 1802        Saudi Arabia  Conventional crude oil - exports  2005  359312.0000
# 1803        Saudi Arabia  Conventional crude oil - exports  2004  339584.0000
# 1804        Saudi Arabia  Conventional crude oil - exports  2003  342871.9931
# 1805        Saudi Arabia  Conventional crude oil - exports  2002  293307.0000
# 1806        Saudi Arabia  Conventional crude oil - exports  2001  300847.0000
# 1807        Saudi Arabia  Conventional crude oil - exports  2000  311673.0000
# 1808        Saudi Arabia  Conventional crude oil - exports  1999  305169.0000
# 1809        Saudi Arabia  Conventional crude oil - exports  1998  339077.0000
# 1810        Saudi Arabia  Conventional crude oil - exports  1997  325499.0000
# 1811        Saudi Arabia  Conventional crude oil - exports  1996  313898.0000
# 1812        Saudi Arabia  Conventional crude oil - exports  1995  323224.0000
# 1813        Saudi Arabia  Conventional crude oil - exports  1994  320373.0000
# 1814        Saudi Arabia  Conventional crude oil - exports  1993  326247.0000
# 1815        Saudi Arabia  Conventional crude oil - exports  1992  328066.0000
# 1816        Saudi Arabia  Conventional crude oil - exports  1991  325295.0000
# 1817        Saudi Arabia  Conventional crude oil - exports  1990  241742.0000

# %%
# display the row in the data set that shows how much oil 
# (in thousand metric tons, unit of the "Quantity" column)
# Denmark exported in 2020 
oil[(oil["Country or Area"]=="Denmark") & (oil["Year"]==2020)]
# Out:
#     Country or Area           Commodity - Transaction  Year  Quantity
# 645         Denmark  Conventional crude oil - exports  2020  1089.145

# %%
# display the part of the data set that shows export quantities over 30 000 
# (thirty thousand) for the year 1990
# (in thousand metric tons, unit of the "Quantity" column)
oil[(oil["Quantity"]>30000) & (oil["Year"]==1990)]
# Out:
#                 Country or Area           Commodity - Transaction  Year  \
# 1007                  Indonesia  Conventional crude oil - exports  1990
# 1038     Iran (Islamic Rep. of)  Conventional crude oil - exports  1990
# 1069                       Iraq  Conventional crude oil - exports  1990
# 1182                     Kuwait  Conventional crude oil - exports  1990
# 1239                      Libya  Conventional crude oil - exports  1990
# 1344                     Mexico  Conventional crude oil - exports  1990
# 1495                    Nigeria  Conventional crude oil - exports  1990
# 1531                     Norway  Conventional crude oil - exports  1990
# 1563                       Oman  Conventional crude oil - exports  1990
# 1817               Saudi Arabia  Conventional crude oil - exports  1990
# 2202       United Arab Emirates  Conventional crude oil - exports  1990
# 2234             United Kingdom  Conventional crude oil - exports  1990
# 2268              USSR (former)  Conventional crude oil - exports  1990
# 2307  Venezuela (Bolivar. Rep.)  Conventional crude oil - exports  1990
#
#       Quantity
# 1007   33820.0
# 1038  110000.0
# 1069   78159.0
# 1182   32620.0
# 1239   54300.0
# 1344   69631.0
# 1495   74892.0
# 1531   66602.0
# 1563   31193.0
# 1817  241742.0
# 2202   93611.0
# 2234   54022.0
# 2268  108551.0
# 2307   65154.0

# %%
# Which countries did not export any oil in 2017?
# (display the subset of the dataframe) 
oil[(oil["Year"]==2017) & (oil["Quantity"]==0)]
# Out:
#                Country or Area           Commodity - Transaction  Year  \
# 275   Bolivia (Plur. State of)  Conventional crude oil - exports  2017
# 1144                     Kenya  Conventional crude oil - exports  2017
# 1496           North Macedonia  Conventional crude oil - exports  2017
#
#       Quantity
# 275        0.0
# 1144       0.0
# 1496       0.0

# %% [markdown]
# ## Task 1d: Zoom in on a subset & explore the data
#
# From now on, we will work with only a **subset** of the data set, looking only at the **most recent year** for which data is availabe. Make sure that you create a copy of the dataframe that you used until now, using the `.copy()` method, so that our manipulations of the subset data frame will not affect the original data frame.

# %%
# copy the part of the data set for the MOST RECENT year into a separate data frame 
# called oilXXXX (XXXX standing for the most recent year)
max(oil["Year"]) # most recent year
# Out:
# 2021

# %%
oil2021 = oil[oil["Year"]==2021].copy()

# %%
# what is the TOTAL quantity of exported oil? (summed over all countries)
# save the value to a variable called total_exports
total_exports = sum(oil2021["Quantity"])
print(total_exports) # over 1.2 million (of thousand metric tons)
# Out:
# 1203622.2712843972

# %%
# sort the rows by descending value of "Quantity" 
# (i.e. the first row should contain the biggest exporter, etc.)
# make sure that you don't just *display* the sorted dataframe, but actually 
# *change* the dataframe into a sorted-by-quantity one
oil2021 = oil2021.sort_values(by = "Quantity", ascending = False)
# equivalent to: oil2021.sort_values(by = "Quantity", ascending = False, inplace = True)

# %%
# add a new column called "perc" to the dataframe; in this column,
# compute, for each country, what percentage of total_exports 
# their exported quantity translates to.
oil2021["perc"] = 100 * oil["Quantity"] / total_exports

# %%
# display the first 10 rows one more time: 
# now you should see what are the biggest 10 exporters in the most recent year?
oil2021.head(10)
# Out:
#          Country or Area           Commodity - Transaction  Year     Quantity  \
# 1786        Saudi Arabia  Conventional crude oil - exports  2021  309427.3000
# 1756  Russian Federation  Conventional crude oil - exports  2021  231600.0000
# 391               Canada  Conventional crude oil - exports  2021  158229.7610
# 2235       United States  Conventional crude oil - exports  2021  146840.1000
# 1500              Norway  Conventional crude oil - exports  2021   78436.8220
# 1313              Mexico  Conventional crude oil - exports  2021   54053.0000
# 49                Angola  Conventional crude oil - exports  2021   52305.8561
# 1532                Oman  Conventional crude oil - exports  2021   38688.1000
# 473             Colombia  Conventional crude oil - exports  2021   31785.0000
# 2203      United Kingdom  Conventional crude oil - exports  2021   30349.1540
#
#            perc
# 1786  25.708007
# 1756  19.241917
# 391   13.146131
# 2235  12.199849
# 1500   6.516731
# 1313   4.490861
# 49     4.345704
# 1532   3.214306
# 473    2.640779
# 2203   2.521485

# %%
# for a country of your choice that is not on the "top 10", 
# find out what is their percentage of total exports?
# (just display the row for that country)
oil2021[oil2021["Country or Area"]=="Romania"] # for example for Romania
# Out:
#      Country or Area           Commodity - Transaction  Year  Quantity  \
# 1741         Romania  Conventional crude oil - exports  2021      34.0
#
#           perc
# 1741  0.002825

# %%
# find out which country exported the most, and which country exported the least;
# what is the ratio (proportion) of the biggest vs. smallest export quantity?

# %%
# biggest export
oil2021[oil2021["Quantity"]==max(oil2021["Quantity"])]
# Out:
#      Country or Area           Commodity - Transaction  Year  Quantity  \
# 1786    Saudi Arabia  Conventional crude oil - exports  2021  309427.3
#
#            perc
# 1786  25.708007

# %%
# smallest export
oil2021[oil2021["Quantity"]==min(oil2021["Quantity"])]
# Out:
#      Country or Area           Commodity - Transaction  Year  Quantity  \
# 1878        Slovenia  Conventional crude oil - exports  2021     0.159
#
#           perc
# 1878  0.000013

# %%
# ratio
max(oil2021["Quantity"])/min(oil2021["Quantity"])
# (almost 2 millino times more)
# Out:
# 1946083.647798742

# %% [markdown]
# ## Task 1e: Write your manipulated data set to a file
#
# Write the data set from the previous file (with data only on the most recent year; and with the added column containig percentages) to a file.

# %%
# write to csv with the help of pandas (you don't need to write the row labels (index) to the file)
oil2021.to_csv("oil2021.csv", index = False)

# %%
# read back into a variable called "df" in & display the first 10 rows to check
df = pd.read_csv("oil2021.csv")
df.head(10)
# Out:
#       Country or Area           Commodity - Transaction  Year     Quantity  \
# 0        Saudi Arabia  Conventional crude oil - exports  2021  309427.3000
# 1  Russian Federation  Conventional crude oil - exports  2021  231600.0000
# 2              Canada  Conventional crude oil - exports  2021  158229.7610
# 3       United States  Conventional crude oil - exports  2021  146840.1000
# 4              Norway  Conventional crude oil - exports  2021   78436.8220
# 5              Mexico  Conventional crude oil - exports  2021   54053.0000
# 6              Angola  Conventional crude oil - exports  2021   52305.8561
# 7                Oman  Conventional crude oil - exports  2021   38688.1000
# 8            Colombia  Conventional crude oil - exports  2021   31785.0000
# 9      United Kingdom  Conventional crude oil - exports  2021   30349.1540
#
#         perc
# 0  25.708007
# 1  19.241917
# 2  13.146131
# 3  12.199849
# 4   6.516731
# 5   4.490861
# 6   4.345704
# 7   3.214306
# 8   2.640779
# 9   2.521485

# %% [markdown]
# # Task 2: Reading in a csv without pandas (advanced!)
#
# Let's try to read in the same data set `oil.csv` without pandas, using only `.reader()` from the built-in `csv` module.
#
# * the data set should be read into a dictionary `oil_dict`
# * the keys of `oil_dict` should correspond to the column names of `oil.csv` (for example, `Year` should be a dictionary key)
# * the values of `oil_dict` should contain the data from the corresponding column as a list (for example, the value of the key `Year` should contain a list `[2021, 2020, 2019, ....]`)
#
# Steps to a **possible** solution: (there are many ways to solve this task!)
#
# 1. import the built-in module `csv`;
# 2. create a "context" in which the csv file is opened (`with open()`... etc)
# 3. within the "context", use the `csv.reader()` iterator to read in the file
# 4. iterate over the return value of `csv.reader()` (using a for loop or list comprehension), the output should be a list of lists (where each item is a row in the csv file)
# 5. use the column names to create dictionary keys, & store the data from the corresponding column in the corresponding dictionary value (the built-in function `enumerate()` and list comprehension can help!)
# 6. you may ignore the lines that appear to have less than 6 columns

# %%
# Step 1: import the csv module
import csv

# %%
# Step 2: create a context to open the file
with open("oil.csv", "r") as opened_file:
    my_reader = csv.reader(opened_file)
    rows = [row for row in my_reader]
rows
# Out:
# [['Country or Area',
#   'Commodity - Transaction',
#   'Year',
#   'Unit',
#   'Quantity',
#   'Quantity Footnotes'],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '547.8',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '577.32',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '631.216',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '582.789',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '488',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '888',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '987',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '1007.22',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '1167',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '920.07',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '597.81',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '586.47',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '221.23',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '240.2',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '244',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '63',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Albania',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '16735.718',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '22181',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '21676',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '24677',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '25227',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '24181',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '23550',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '28130',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '31881',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '32424',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '32974',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '34731',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '39179',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '43248',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '43954',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '44940',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '41280',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '33725',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '25420',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '19583',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '21412',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '19289',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '19294',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '17280',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '18171',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '15417',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '15469',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '14289',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '15634',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '16182',
#   ''],
#  ['Algeria',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '14007',
#   '1'],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '52305.8561',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '59228.0691',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '63861.7106',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '69042.9732',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '76359.3325',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '81100.0762',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '85253.27',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '79631.388',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '83470',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '83390',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '77278',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '85997',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '88622',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '92469',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '82943',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '67934',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '60302',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '47105',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '41430',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '42668',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '34367',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '34310',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '34448',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '34386',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '32723',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '30794',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '28065',
#   ''],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '24794',
#   '1'],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '23700',
#   '1'],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '25000',
#   '1'],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '23250',
#   '1'],
#  ['Angola',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '22000',
#   '1'],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '3077',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '4007.317',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '3389',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '3197',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '1481',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '2643',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '1878',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '1898',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '1943',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '3080',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '3057',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '2861',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '4680',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '2835',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '2922',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '4495',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '7653',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '9013',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '11802',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '13683',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '14767',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '14249',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '13817',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '16496',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '17104',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '16691',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '13920',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '10467',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '4454',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '3042',
#   '1'],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '1272',
#   ''],
#  ['Argentina',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '917',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '12216.443',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '12895.585',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '11074.884',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '9792.313',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '9697.737',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '10669',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '11404',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '11099',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '11715',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '13022',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '14826',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '13661',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '12503',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '11654',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '11698',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '9409',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '11389',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '12973',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '15556',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '19128',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '19421',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '15338',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '9906',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '10551',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '8866',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '8059',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '8704',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '7153',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '7812',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '7035',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '7210',
#   ''],
#  ['Australia',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '5348',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '63',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '61',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '51',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '44',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '25',
#   ''],
#  ['Austria',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '51',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '24830.5',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '27704.1',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '30141',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '30488.2',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '32479',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '32843',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '32903',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '34260',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '34728',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '37268',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '42659',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '44332',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '36858',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '34780',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '24820',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '14296',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '9048',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '8997',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '8881',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '8462',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '5638',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '5684',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '1903',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '233',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Azerbaijan',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '7449',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '7439',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '7654',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '7693',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '7601',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '7724',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '7453',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '7693',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '7120',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '6649',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '7475',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '7524',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '7579',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '7442',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '7369',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '7393',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '7496',
#   ''],
#  ['Bahrain',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '7510',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '47.5177304964539',
#   '1'],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '47.5066193853428',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '32.1853427895981',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '28.1111111111111',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '32.017778',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '34.308038',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '33.756501',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '29',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '34.3',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '37.6',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '39.8',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '42.2',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '38.3',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '39.5',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '46',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '49.863',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '63.377',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '63.377',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '63.377',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '80',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '63',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '77',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '99',
#   ''],
#  ['Barbados',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '69',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '1217',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '1649',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '1640',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '1621',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '1617',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '1615',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '1617',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '1619',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '1645',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '1676',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '1716',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '1453',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '851',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '1138',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '1346',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '1051',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '801',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '601',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '401',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '351',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '350',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '382',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '400',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '300',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '200',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '250',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '284',
#   ''],
#  ['Belarus',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '1058',
#   ''],
#  ['Belgium',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '192.2',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '10.4964539007092',
#   '1'],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '10.4018912529551',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '30.8108747044917',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '29.2157947990544',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '39.082137',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '49.049308',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '59.191382',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '86.04873',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '67.991756',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '128.077293',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '186.597729',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '206.690307',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '192.437352',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '172.539007',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '144.165485',
#   ''],
#  ['Belize',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '112.6',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '61',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '64',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '83',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '95',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '129',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '154',
#   ''],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '136',
#   '1'],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '197',
#   '1'],
#  ['Benin',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '206',
#   '1'],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '59',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '384',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '418',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '40',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '139',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '204',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '217',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '241',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '133',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '91',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '126',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '173',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '67',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '63',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '17',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '49',
#   ''],
#  ['Bolivia (Plur. State of)',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '70169',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '62866',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '55164',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '53337',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '43419',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '37794',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '26619',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '20142',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '27051',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '30660',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '32028',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '26660',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '21970',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '21373',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '18666',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '13923',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '12262',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '12262',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '11917',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '5618',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '1646',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '30',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '130',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '104',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '677',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brazil',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '3569.514',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '5312.104',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '4571',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '4871',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '5209',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '5763',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '5362',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '5822',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '6920',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '6740',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '7342',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '7064',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '8162',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '8523',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '10345.3582',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '9544.1555',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '9551.7955',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '9809.1031',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '9511.3247',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '9050',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '9058',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '8373',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '7136',
#   '1'],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '7920',
#   '1'],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '8030',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '8369',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '8684',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '8489',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '8800',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '8079',
#   ''],
#  ['Brunei Darussalam',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '7333',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '3683.182',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '3283.734',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '2904.295',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '3488.042',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '4348',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '4270',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '3838',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '3298',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '2845',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '2698',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '2821',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '3237',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '3826',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '3926',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '4505',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '4157',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '4648',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '4957',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '5146',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '5452',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '5717',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '5427',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '6114',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '5456',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '5280',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '4945',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '3830',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '6170',
#   '1'],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '6620',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '7010',
#   ''],
#  ['Cameroon',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '7410',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '158229.761',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '156209.399',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '166269.65',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '157340',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '144695',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '143984',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '123175',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '117961',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '109828',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '95715',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '89540',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '78760',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '75017',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '76927',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '73599',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '78657',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '74355',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '67130',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '60993',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '57150',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '56844',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '58425',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '51870',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '56777',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '51625',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '48178',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '44887',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '41945',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '38978',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '34540',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '31960',
#   ''],
#  ['Canada',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '27061',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '6400',
#   '1'],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '6300',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '6031.4',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '5762.8',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '5092.3',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '5801.1',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '6492.8',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '4573.9',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '4212',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '5163',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '5609',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '6153.5',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '5986.4',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '6465.173',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '7104.8024',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '7806.2715',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '8740.6357',
#   ''],
#  ['Chad',
#   'Conventional crude oil - exports',
# ...
#   '1994',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '106',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '101',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '333',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '30',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '34',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '194',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '375',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '706',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '110',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '135',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '690',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '548',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '703',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '1108',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '647',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '1322',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '1030',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '3217',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '1741',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '1389',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '3583',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '1778',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '763',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '1121',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '108',
#   ''],
#  ['Germany',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '208',
#   ''],
#  ['Germany, Fed. R. (former)',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '7916.55',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '9636.89',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '10140.7',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '8860',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '8141',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '4272',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '5209',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '5386',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '5150',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '3776',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '3533',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Ghana',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '85.057',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '88.979',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '242.199',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '201.536',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '163',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '156',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '80',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '59',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '145',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '258',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '684',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '847',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '998',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '1063',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '1056',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '1054',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '918',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '812',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '1105',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '387',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '116',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '204',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '260',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '632',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '425',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '723',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '470',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '678',
#   ''],
#  ['Greece',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '1233',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '191.217',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '268.393',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '308.694',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '392.62',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '367.7',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '431.3',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '410.8',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '440.4',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '488',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '527',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '555',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '631',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '706',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '708',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '831',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '892',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '1043',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '1231',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '1259',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '1061',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '934.06',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '1047',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '1205',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '892',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '641',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1995',
#   'Metric tons,  thousand',
#   '407',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1994',
#   'Metric tons,  thousand',
#   '232',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1993',
#   'Metric tons,  thousand',
#   '295',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1992',
#   'Metric tons,  thousand',
#   '248',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1991',
#   'Metric tons,  thousand',
#   '159',
#   ''],
#  ['Guatemala',
#   'Conventional crude oil - exports',
#   '1990',
#   'Metric tons,  thousand',
#   '164',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2021',
#   'Metric tons,  thousand',
#   '134',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '199',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '191',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '394',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '161',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '75',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '96',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '10',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '61',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '475',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '596',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '811',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '344',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '136',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '1998',
#   'Metric tons,  thousand',
#   '0',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '1997',
#   'Metric tons,  thousand',
#   '54',
#   ''],
#  ['Hungary',
#   'Conventional crude oil - exports',
#   '1996',
#   'Metric tons,  thousand',
#   '15',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2020',
#   'Metric tons,  thousand',
#   '5105.55555555556',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2019',
#   'Metric tons,  thousand',
#   '3525.724',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2018',
#   'Metric tons,  thousand',
#   '8929',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2017',
#   'Metric tons,  thousand',
#   '12035',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2016',
#   'Metric tons,  thousand',
#   '15131',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2015',
#   'Metric tons,  thousand',
#   '13542',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2014',
#   'Metric tons,  thousand',
#   '11091',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2013',
#   'Metric tons,  thousand',
#   '10450',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2012',
#   'Metric tons,  thousand',
#   '15757',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2011',
#   'Metric tons,  thousand',
#   '18520',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2010',
#   'Metric tons,  thousand',
#   '18048',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2009',
#   'Metric tons,  thousand',
#   '18257',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2008',
#   'Metric tons,  thousand',
#   '13698',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2007',
#   'Metric tons,  thousand',
#   '17416',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2006',
#   'Metric tons,  thousand',
#   '15027',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2005',
#   'Metric tons,  thousand',
#   '16056',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2004',
#   'Metric tons,  thousand',
#   '20250',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2003',
#   'Metric tons,  thousand',
#   '22626',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2002',
#   'Metric tons,  thousand',
#   '25262',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2001',
#   'Metric tons,  thousand',
#   '29412',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '2000',
#   'Metric tons,  thousand',
#   '26145',
#   ''],
#  ['Indonesia',
#   'Conventional crude oil - exports',
#   '1999',
#   'Metric tons,  thousand',
#   '33477',
#   ''],
#  ...]

# %%
# initiate an empty dictionary
oil_dict = {}

for i, colname in enumerate(rows[0]):
    
    print(f"iteration step {i}: filling column {colname}")

    oil_dict[colname] = [row[i] for row in rows[1:] if len(row)==len(rows[0])]
# Out:
# iteration step 0: filling column Country or Area
# iteration step 1: filling column Commodity - Transaction
# iteration step 2: filling column Year
# iteration step 3: filling column Unit
# iteration step 4: filling column Quantity
# iteration step 5: filling column Quantity Footnotes

# %%
# this worked fine for our string values
# (and because we also dropped rows with NA values in the oil dataframe)
all(oil_dict["Country or Area"] == oil["Country or Area"])
# Out:
# True

# %%
# for the columns containing numeric values,
# in the dictionary we need to convert str to float/int:
oil_dict["Year"] = [int(y) for y in oil_dict["Year"]]
# (using list comprehension to replace each year y, as of now a string 
# (which was read in by csv.reader()), by the corresponding integer
